# %%
import pandas as pd

# %%
df = pd.read_json(r'C:\Users\seagate pc\Desktop\BT4222\Group Project\Data_Mining\Project\reviews.json')

# %%
df.reset_index(drop = True)
# Out:
#              restaurant_name  \
# 0             Guzman Y Gomez
# 1             Guzman Y Gomez
# 2             Guzman Y Gomez
# 3                  The Beast
# 4                  The Beast
# 5                  The Beast
# 6                  The Beast
# 7                  The Beast
# 8                  The Beast
# 9                  The Beast
# 10                 The Beast
# 11                 The Beast
# 12                 The Beast
# 13            Guzman Y Gomez
# 14                 The Beast
# 15                 The Beast
# 16                 The Beast
# 17                 The Beast
# 18                 The Beast
# 19                 The Beast
# 20                 The Beast
# 21                      Loof
# 22                      Loof
# 23                      Loof
# 24            Guzman Y Gomez
# 25                      Loof
# 26                      Loof
# 27                      Loof
# 28                      Loof
# 29                      Loof
# ..                       ...
# ...

# %%
df.shape
# Out:
# (493, 4)

# %%
df.restaurant_name.value_counts()
# Out:
# edge                                21
# The Naked Finn                      21
# MTR 1924                            21
# Liao Fan Hawker Chan                21
# Din Tai Fung                        21
# Salt Grill & Sky Bar                20
# Song Fa Bak Kut Teh                 20
# Hoshino Coffee                      20
# Vatos Urban Tacos                   20
# CUT                                 20
# Tian Tian Hainanese Chicken Rice    20
# The Beast                           20
# Soup Nutsy                          20
# Hokkaido Ramen Santouka             20
# Tim Ho Wan                          20
# Zhong Guo La Mian Xiao Long Bao     20
# Jumbo Seafood                       20
# Jimmy Monkey Cafe & Bar             20
# Swee Choon Tim Sum                  20
# Spago By Wolfgang Puck              20
# Chili's                             20
# Loof                                20
# Waku Ghin                           19
# Guzman Y Gomez                      17
# ...

# %%
df.stars.value_counts().sort_index()
# Out:
# 1     26
# 2     28
# 3     74
# 4    182
# 5    183
# Name: stars, dtype: int64
