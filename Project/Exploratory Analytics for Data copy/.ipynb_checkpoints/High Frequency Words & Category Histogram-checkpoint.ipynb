# %%
import pandas as pd
import inflect
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-157-60247ca8baa7> in <module>
#       1 import pandas as pd
# ----> 2 import inflect
#
# ModuleNotFoundError: No module named 'inflect'

# %%
reviews = pd.read_csv("yelp_singapore_restaurants_reviews.csv", encoding = "ISO-8859-1")
reviews.head()
# Out:
#           restaurant                                            content  \
# 0  Sungei Road Laksa  The food has been phenomenal Laksa was awesome...
# 1  Sungei Road Laksa  When we got to this hawker center, we immediat...
# 2  Sungei Road Laksa  Laksa is a popular Southeast Asia spicy noodle...
# 3  Sungei Road Laksa  Laska is not my thing and after trying this st...
# 4  Sungei Road Laksa  Laksa here is so good! Tasty and rich in flavo...
#
#    stars                 date
# 0      5  2018-12-18T00:00:00
# 1      4  2019-12-21T00:00:00
# 2      4  2019-05-16T00:00:00
# 3      4  2019-04-28T00:00:00
# 4      5  2019-01-03T00:00:00

# %%
reviews.tail()
# Out:
#                   restaurant  \
# 10121  Ocean Curry Fish Head
# 10122  Ocean Curry Fish Head
# 10123  Ocean Curry Fish Head
# 10124  Ocean Curry Fish Head
# 10125          Shan E Punjab
#
#                                                  content  stars  \
# 10121  I'm surprised at how good the fish head curry ...      5
# 10122  Absolutely yummy goodness. ýýýýThe restaurant ...      4
# 10123  $45 for 2... curry fishhead plus 3 side dishes...      4
# 10124  I'll be frank to say that the food is not chea...      4
# 10125  This is hawker stall food at its finest. We ha...      5
#
#                       date
# 10121  2016-01-31T00:00:00
# 10122  2018-07-01T00:00:00
# 10123  2014-12-31T00:00:00
# 10124  2014-12-31T00:00:00
# 10125  2018-07-23T00:00:00

# %%
reviews.shape
# Out:
# (10126, 4)

# %%
restaurant_names = []

for i in reviews['restaurant']:
    if not i in restaurant_names:
        restaurant_names.append(i)
        
len(restaurant_names)
# Out:
# 770

# %%
restaurant_dict = dict()

for index, i in enumerate(restaurant_names):
    restaurant_dict[i] = index
    
restaurant_dict
# Out:
# {'Sungei Road Laksa': 0,
#  'Holycrab': 1,
#  'Tian Tian Hainanese Chicken Rice': 2,
#  'Song Fa Bak Kut Teh': 3,
#  'Jumbo Seafood': 4,
#  'National Kitchen By Violet Oon': 5,
#  'Liao Fan Hawker Chan': 6,
#  'Din Tai Fung': 7,
#  'Khansama Tandoori': 8,
#  'Tim Ho Wan': 9,
#  'Corner House': 10,
#  'Coriander Leaf': 11,
#  'Vatos Urban Tacos': 12,
#  'Hong Kong Style Chee Cheong Fun': 13,
#  'Burnt Ends': 14,
#  'The Coconut Club': 15,
#  'Zhong Guo La Mian Xiao Long Bao': 16,
#  '328 Katong Laksa': 17,
#  'Hokkaido Ramen Santouka': 18,
#  'Wee Nam Kee Chicken Rice': 19,
#  'JustIN Flavours of Asia': 20,
#  'Komala Vilas Restaurant': 21,
#  'edge': 22,
#  'Old Airport Road Food Centre': 23,
#  'Spago By Wolfgang Puck': 24,
#  'Usman Restaurant': 25,
#  'Sawadee Thai Cuisine': 26,
#  'Blanco Court Prawn Mee': 27,
#  'Tai Hwa Pork Noodle': 28,
#  'Zam Zam Restaurant': 29,
#  'A Noodle Story': 30,
#  'Outram Park Fried Kway Teow Mee': 31,
#  'Tanglin Food Hall': 32,
#  'MTR 1924': 33,
#  'The Naked Finn': 34,
#  'Hainanese Delicacy Chicken Rice': 35,
#  'Hong Kong Street Family Restaurant': 36,
#  'Kailash Parbat': 37,
#  'The Banana Leaf Apolo': 38,
#  'Shake Shack': 39,
#  'Swee Choon Tim Sum': 40,
#  'Two Men Bagel House': 41,
#  'Three Buns': 42,
#  'Founder Bak Kut Teh': 43,
#  'CUT': 44,
#  'Mrs Pho': 45,
#  'Man Man Japanese Unagi': 46,
#  'Satay By The Bay': 47,
#  'Yardbird Southern Table & Bar': 48,
#  'Mrs Pho House Rangoon': 49,
#  'The Halia': 50,
#  'Violet Oon Satay & Grill': 51,
#  'Club55': 52,
#  "Fynn's": 53,
#  'Ah Tai Hainanese Chicken Rice': 54,
#  'Everest Kitchen': 55,
#  'Food Republic': 56,
#  'Lighthouse Bistro': 57,
#  'Heart of Darkness Singapore': 58,
#  'Kampong Glam Cafe': 59,
#  'Padi': 60,
#  'Salt Grill & Sky Bar': 61,
#  'Jumbo': 62,
#  'Waku Ghin': 63,
#  'The RiceTable': 64,
#  "Chef Kang's Noodle House": 65,
#  'The Other Room': 66,
#  'Empress': 67,
#  'La Strada': 68,
#  'Amaravati': 69,
#  'Yan kee Noodle House': 70,
#  'Stuttgart Blackforest Boutique S-Cafe': 71,
#  'Once Upon A Thyme': 72,
#  'The Sushi Bar': 73,
#  'NUDE Seafood': 74,
#  'Tono Cevicheria': 75,
#  'Fat Cow': 76,
#  'Keng Eng Kee Seafood': 77,
#  'Bakalaki Greek Taverna': 78,
#  'Nanyang Old Taste': 79,
#  'JB Ah Meng': 80,
#  'Yakinikutei Ao-Chan': 81,
#  'Red House': 82,
#  'Pistachio': 83,
#  'Chui Huay Lim Teochew Cusine': 84,
#  'Johor Road Boon Kee Pork Porridge': 85,
#  'FOC': 86,
#  'Indocafe The White House': 87,
#  'Artichoke Cafe & Bar': 88,
#  'The Original Katong Laksa': 89,
#  "Mr and Mrs Mohgan's Super Crispy Roti Prata": 90,
#  "Allauddin's Briyani": 91,
#  'Warehouse Bistro': 92,
#  'Pek Kio Market & Food Centre': 93,
#  "Tolido's Espresso Nook": 94,
#  'Lavender Food Hub': 95,
#  'HOME Bar & Kitchen': 96,
#  'Char Restaurant': 97,
#  'CreatureS': 98,
#  'Black Tap': 99,
#  'The Ottoman Room': 100,
#  'Tandoori Culture': 101,
#  'Da Lian Traditional Noodles': 102,
#  'Herbivore': 103,
#  'Odette': 104,
#  '15 Stamford by Alvin Leung': 105,
#  'Fragrant Garden': 106,
#  'Famous Sungei Road Trishaw Laksa': 107,
#  'Publico': 108,
#  'Penang Seafood Restaurant': 109,
#  'Brazil Churrasco': 110,
#  'Beach Road Kitchen': 111,
#  'House of Peranakan Petit': 112,
#  'Limaa': 113,
#  'The Malayan Council': 114,
#  'Vietnamese Stall - Sim Lim Square Food Court': 115,
#  'Jian Bo Shui Kueh': 116,
#  'My Awesome Cafe': 117,
#  'Hawaiian Kitchen ALOHA Ma Maison': 118,
#  'Waterfall Cafe': 119,
#  'Tabbouleh': 120,
#  'Ki-sho': 121,
#  'Going Om': 122,
#  'Riverside Indonesian BBQ': 123,
#  'Sidewalk Food Place': 124,
#  'Labyrinth': 125,
#  'Preludio': 126,
#  'Hai Di Lao': 127,
#  'The Tippling Club': 128,
#  'Haikee Brothers': 129,
#  'Joo Chiat Road': 130,
#  'Redpan': 131,
#  'Basilico': 132,
#  'Co Hai Banh Mi': 133,
#  'Mellben Seafood': 134,
#  'Colony': 135,
#  'Singapore Seafood Republic': 136,
#  'Pu Tien': 137,
#  'The Bento People': 138,
#  'Wolf Burgers': 139,
#  "Fatboy's The Burger Bar": 140,
#  'Ya Kun Kaya Toast': 141,
#  'Curious Palette': 142,
#  'Imperial Treasure Fine Chinese Cuisine': 143,
#  'Lolla': 144,
#  'No. 18 Zion Road Char Kway Teow': 145,
#  'Bread Street Kitchen': 146,
#  'Astons Specialities': 147,
#  'The Royals Steakhouse': 148,
#  'Potato Head Folk': 149,
#  'Soi 47 Thai Food': 150,
#  'Thye Hong Singapore Heritage Food': 151,
#  'Red House Seafood Restaurant': 152,
#  'Crab Song': 153,
#  'Jai Thai': 154,
#  'ShuKuu Izakaya': 155,
#  'Rui Xiang Restaurant': 156,
#  'Sin Heng Kee Porridge': 157,
#  'Ananda Bhavan': 158,
#  'Druggists': 159,
#  'Boca Restaurant': 160,
#  'Fook Kin': 161,
#  'Ah Loy Thai': 162,
#  'City Hot Pot Shabu Shabu': 163,
#  'Buona Terra': 164,
#  'Merci Marcel': 165,
#  'Nicolas Le Restaurant': 166,
#  'Ippudo': 167,
#  'The Peranakan': 168,
#  'Luk Lu Eating House': 169,
#  'The Kitchen Table': 170,
#  'Red Eye Smokehouse': 171,
#  'Susan Chan Food': 172,
#  'hans im glýýýýck': 173,
#  'My Little Tapas Bar': 174,
#  'Bismillah Biryani': 175,
#  'Twenty Eight Cafe': 176,
#  'Streets of London @ British Hainan': 177,
#  'ADRIFT': 178,
#  'Fat Bird': 179,
#  'iO Italian Osteria': 180,
#  'Zhong Hua Steamboat': 181,
#  "Wheeler's Yard": 182,
#  'Brunches Cafe': 183,
#  'Taste Paradise': 184,
#  'Oporto': 185,
#  'Boon Tong Kee': 186,
#  'Yakiniku Yazawa': 187,
#  'Byblos Grill': 188,
#  'Long Beach Seafood': 189,
#  'Mei Toy Thai Food': 190,
#  'Joo Bar': 191,
#  'The Meeting Place': 192,
#  'Boulevard Bayfront': 193,
#  'Nakhon Kitchen': 194,
#  'The Black Swan': 195,
#  'Long Ji Zi Char': 196,
#  'The Garden @ Sentosa': 197,
#  'OLA Cocina del Mar': 198,
#  'Inle Myanmar': 199,
#  'Mr You Tiao': 200,
#  'Seiwaa Okonomiyaki & Teppanyaki Restaurant': 201,
#  'Arkadas Cafe': 202,
#  'Tandoori Corner North Indian Curry House': 203,
#  'The Black Sheep Cafe': 204,
#  'HaiDiLao Hotpot': 205,
#  'Five Star Hainanese Chicken Rice': 206,
#  'LAVO Italian Restaurant & Rooftop Bar': 207,
#  'Penang Place': 208,
#  'Shou la shou Beijing Restaurant': 209,
#  'Looýýýýýýs Hainanese Curry Rice': 210,
#  'Traditional Haig Road Putu Piring': 211,
#  'Marchýýýý': 212,
#  "Big Bern's American Grill": 213,
#  'Po Restaurant': 214,
#  'Escape Restaurant & Lounge': 215,
#  'Taste Of Morroco': 216,
#  'Food Village @ Takashimaya': 217,
#  'Long Beach King Seafood': 218,
#  'Uni Gallery': 219,
#  'Melt Cafýýýý': 220,
#  'Super Loco Customs House': 221,
#  'Kazu Sumiyaki': 222,
#  'Sin Ming Roti Prata': 223,
#  'IndoChine': 224,
#  'Botanist': 225,
#  'The Lawn': 226,
#  "Arnold's Fried Chicken": 227,
#  'The Dempsey Cookhouse & Bar': 228,
#  'Curry Village Banana Leaf': 229,
#  'Seafood Paradise': 230,
#  "Momma Kong's Crab Shack": 231,
#  'Mya Nandar': 232,
#  'Saigon Baguette': 233,
#  'The Daily Cut': 234,
#  'Cook & Brew': 235,
#  'Aromas Of India': 236,
#  'Owls Brew': 237,
#  'ýýýýýýýýýýýýýýýýýýýýýýýý Mongkok Dim Sum': 238,
#  'Five Guys': 239,
#  'Bendemeer Prawn Noodle': 240,
#  'Maison Ikkoku Restaurant & Bar': 241,
#  'Le Bistrot Du Sommelier': 242,
#  'Imperial Treasure Nan Bei Restaurant': 243,
#  'Joyden Treasures': 244,
#  'Bigmama': 245,
#  'Kok Sen Restaurant': 246,
#  'Por Kee Eating House': 247,
#  'Wee Nam Kee Hainanese Chicken Rice': 248,
#  'PS.Cafe': 249,
#  'Li Bai Cantonese Restaurant': 250,
#  'Newton Circus': 251,
#  'Vietnamese - Authentic Vietnamese Cuisine': 252,
#  'Thien Long Vietnamese Restaurant': 253,
#  'The BOILER Seafood Bar & Beer': 254,
#  'Saveur': 255,
#  'Tong Kee Chicken Rice': 256,
#  'Ramen Keisuke Tori King': 257,
#  'Momiji Japanese Buffet Restaurant': 258,
#  'No Signboard Seafood Restaurant': 259,
#  'Mahota Commune': 260,
#  "Maggie Joan's": 261,
#  'Moc Quan': 262,
#  'Grain Traders': 263,
#  'Xin Mei Xiang Lor Mee': 264,
#  'Toast Box': 265,
#  'Amber Restaurant': 266,
#  'Shahi Maharani': 267,
#  'Zhen Hao Lor Mee': 268,
#  'Chabuton': 269,
#  'Heng Gi Goose & Duck Rice': 270,
#  'Meat And Green': 271,
#  'Dancing Crab': 272,
#  'Paradise Dynasty': 273,
#  'Dolphins': 274,
#  "Ruth's Chris Steak House": 275,
#  'Old Street Bak Kut Teh': 276,
#  'Colonial Club': 277,
#  'Entre Nous Creperie': 278,
#  'Wang Dae Bak Korean BBQ': 279,
#  'Happy Tummy': 280,
#  'Geylang Lorong 9 Beef Kway Teow': 281,
#  'Cafýýýý Iguana': 282,
#  'Hamburg Steak Keisuke': 283,
#  'LDM Charcoal BBQ Restaurant': 284,
#  'Alliance Seafood': 285,
#  'Kafe Utu': 286,
#  'French Ladle': 287,
#  'DB Bistro Moderne': 288,
#  'Kai Sushi And Robatayaki': 289,
#  "Gerry's Grill Esplanade": 290,
#  'Super Siam Thai Restaurant': 291,
#  'Makanan Bollywood Restaurant': 292,
#  'Hawkerman': 293,
#  'Hong Kong Dim Sum': 294,
#  'The Landmark': 295,
#  'Lai Wah Restaurant': 296,
#  'Imperial Treasure': 297,
#  'Annalakshmi': 298,
#  'Alakai': 299,
#  'Origin Grill & Bar': 300,
#  'Ash & Elm': 301,
#  'Zhen Zhen Porridge': 302,
#  'Murugan Idli Shop': 303,
#  'Cibo Italiano': 304,
#  'Shanghai Ren Jia': 305,
#  'Bosses Restaurant': 306,
#  'YAYOI': 307,
#  'Meatsmith Little India': 308,
#  'Aji-ichi': 309,
#  'Third & Sixth Bistrobar': 310,
#  'Thai Boat Noodles @BaanThai Kitchen': 311,
#  'Old Hen Kitchen': 312,
#  'Fotia': 313,
#  'Chir Chir': 314,
#  'Shang Palace': 315,
#  'Marrakesh Moroccan Lounge': 316,
#  'Blue Ginger': 317,
#  'Tonkatsu Ma Maison': 318,
#  'Kilo': 319,
#  "Samy's Curry": 320,
#  'Ssikkek Korean Grill BBQ Buffet': 321,
#  'Kopi Tiam': 322,
#  'Steamboat Restaurant': 323,
#  'Wakey Wakey': 324,
#  'Tsui Wah': 325,
#  'Alaturka': 326,
#  'Candlenut': 327,
#  'Bee Cheng Hiang - New Bridge Road': 328,
#  'Shuang Shun Chicken Rice': 329,
#  'Old Chengdu Sichuan Cuisine': 330,
#  'My Little Spanish Place': 331,
#  'Crystal Jade Kitchen': 332,
#  'Best Satay': 333,
#  'The Dining Room': 334,
#  'Alati': 335,
#  'Mellben Signature': 336,
#  'Aroy Dee': 337,
#  'BK Eating House': 338,
#  'Dempsey Hill': 339,
#  'Whampoa Keng': 340,
#  'Gajalee': 341,
#  'Katanashi': 342,
#  'Swee Guan Hokkien Mee': 343,
#  'New Ubin Seafood': 344,
#  'Inasal': 345,
#  'Three Peacocks': 346,
#  'Katong Delights': 347,
#  'SBCD Tofu Millenia Walk': 348,
#  'Hopheads': 349,
#  'The Union Bar': 350,
#  'Jaan': 351,
#  'Maki-San': 352,
#  'Teng Bespoke Japanese Vegetarian Dining': 353,
#  'Humpback': 354,
#  'Pita Pan': 355,
#  'Toa Payoh Hwa Heng Beef Noodles': 356,
#  'Jia Xiang Nasi Lemak': 357,
#  'Tiong Bahru Bakery': 358,
#  'Flying Monkey': 359,
#  'Hajah Maimunah': 360,
#  'Unique Pot': 361,
#  'Nox - Dine in the Dark': 362,
#  'The Study': 363,
#  'Kim Choo Kueh Chang': 364,
#  'Golden Jade Restaurant Culinary Group': 365,
#  'Spize': 366,
#  'Nan Hua Chang Seafood Eating House': 367,
#  'Talay Thai': 368,
#  'KWAY Hojiak': 369,
#  'Paulaner Brýýýýuhaus Singapore': 370,
#  'The Blue Ginger': 371,
#  'Patissez': 372,
#  'Sakae Teppanyaki': 373,
#  'Ya Hua Bak Kut Teh': 374,
#  'Ponggol Nasi Lemak': 375,
#  'Employees Only': 376,
#  'Chatterbox': 377,
#  'The Guild': 378,
#  'Little Vietnam Restaurant & Cafe': 379,
#  'PappaRich': 380,
#  'Gantetsu - Ramen Champion': 381,
#  'Misato': 382,
#  'Killiney Kopitiam': 383,
#  "Luke's Oyster Bar & Chop House": 384,
#  'Binomio': 385,
#  'Isle Eating House': 386,
#  "Shanthee's Curry Restaurant": 387,
#  'Seow Choon Hua Restaurant': 388,
#  'Chettinadu New': 389,
#  'Tian Jin Fong Kee': 390,
#  'Dumpling Darlings': 391,
#  'Shabu Shabu Gen': 392,
#  'Ming Chung Restaurant': 393,
#  'Plate': 394,
#  'Som Tam': 395,
#  'Black Knight Hotpot': 396,
#  'Masa Steak & Hamburg': 397,
#  'Leong Kee Bak Kut Teh': 398,
#  'Gyu-Kaku': 399,
#  'Dover Rd Hawker Centre': 400,
#  'The Beast': 401,
#  'Urban Bites Mediterranean Cuisine': 402,
#  "Jaggi's Northern Indian Cuisine": 403,
#  'Sichuan Village restaurant': 404,
#  'Platform 1094': 405,
#  'Marina Food Court': 406,
#  'Al Borgo Italian Restaurant': 407,
#  'The Garden Grille': 408,
#  'Rang Mahal': 409,
#  'Keisuke Tonkotsu King': 410,
#  'Knots Cafe & Living': 411,
#  'Afterglow': 412,
#  'Katong Keah Kee': 413,
#  'Don Lechon': 414,
#  'Fisk': 415,
#  'Sushi Kimura Singapore': 416,
#  "Werner's Oven": 417,
#  'Jew Kit': 418,
#  'Dim Sum Haus': 419,
#  'Ikoi Japanese Restaurant': 420,
#  'Craftsmen Specialty Coffee': 421,
#  'Wah Kee Big Prawn Noodles': 422,
#  'Meat Smith': 423,
#  'Fluff Bakery': 424,
#  'Al Afrose Restaurant': 425,
#  "Mama's Kent Penang Delights": 426,
#  'Marukyu': 427,
#  'Waa Cow!': 428,
#  'Su Korean Cuisine': 429,
#  'Pollen': 430,
#  'Haramiya Japanese BBQ Restaurant': 431,
#  'Warong Nasi Pariaman': 432,
#  'Hambaobao': 433,
#  'Hyang Yeon': 434,
#  'Subarashii Grill & Bar': 435,
#  'Lao You Xuan Noodle Kitchen': 436,
#  'Nanjing Restaurant': 437,
#  'Heng Kee Curry Chicken Mee': 438,
#  'Gangnam Garden': 439,
#  'Beef Yakiniku Dining Yakiniquest': 440,
#  'Iskina Cebu': 441,
#  'Loy Kee Best Chicken Rice': 442,
#  'Astons Steak & Salad': 443,
#  'Soi 19 Thai Wanton Mee': 444,
#  'Smýýýýr': 445,
#  'Crystal Jade Steamboat': 446,
#  'Beirut Grill': 447,
#  'Cheng Mun Chee Kee Pig Organ Soup': 448,
#  "Violet Oon's Kitchen": 449,
#  'Teochew Restaurant Huat Kee': 450,
#  'Broadway Food Court': 451,
#  'The White Rabbit': 452,
#  "Wanton Seng's Noodle Bar": 453,
#  'Jalan Sultan Prawn Mee': 454,
#  'Cheek Bistro': 455,
#  'Makan Matters': 456,
#  'Sari Ratu': 457,
#  'Tsuru-Koshi Udon': 458,
#  'Yao Fa Wanton Mee': 459,
#  'Mezza9': 460,
#  'Fat Prince': 461,
#  'Flutes': 462,
#  'PS Cafe': 463,
#  "Osteria L'operetta Pizzeria": 464,
#  'Xiang Signature': 465,
#  'Bay Leaf Indian Curry House': 466,
#  'Builders Cafe': 467,
#  'Ristorante Takada': 468,
#  'Song Garden': 469,
#  'New Rong Ge Liang Hong Kong Roast': 470,
#  'Food Garden': 471,
#  'Pizzaface': 472,
#  'Tian Tian Seafood Restaurant': 473,
#  '2it & Drink': 474,
#  'Ting Heng Seafood Restaurant': 475,
#  'The Bao Makers': 476,
#  'FatPapas': 477,
#  'Tsuta Japanese Soba Noodles': 478,
#  'Rhubarb Le Restaurant': 479,
#  'Madura': 480,
#  "Sakunthala's": 481,
#  'Big Street': 482,
#  'May May': 483,
#  'Berseh Food Centre': 484,
#  'Palm Beach Seafood': 485,
#  'StraitsKitchen': 486,
#  'Longqing Hotpot': 487,
#  'Elemen': 488,
#  'Aura': 489,
#  'Il Fiore': 490,
#  'Dallas Restaurant & Bar': 491,
#  'Singapore Swimming Club': 492,
#  'Ginger at PARKROYAL': 493,
#  'Restaurant Zen': 494,
#  'Neko no Niwa': 495,
#  'The English House by Marco Pierre White': 496,
#  'Brawn & Brains Coffee': 497,
#  'Pappamia Restaurant': 498,
#  'Ba.li.ba': 499,
#  'La Brasserie': 500,
#  'Dolce Vita': 501,
#  'Hung Kang Teochew Restaurant': 502,
#  'Spuds And Aprons': 503,
#  'Park Bench Deli': 504,
#  'Summer Palace': 505,
#  'Capitol Milk Bar': 506,
#  'Treasures by Imperial Treasure Yi Dian Xin': 507,
#  'Cho Omakase': 508,
#  'Cafe De Hong Kong': 509,
#  'Privýýýý': 510,
#  'Hansang Korean Family': 511,
#  "D'Good Cafe": 512,
#  "Collin's Grill": 513,
#  'Plain Vanilla Bakery': 514,
#  'Sin Huat Seafood Restaurant': 515,
#  "Kim's Fried Hokkien Prawn Mee Stall": 516,
#  'Classic Lao Di Fang Vegetarian': 517,
#  'Selera Rasa Nasi Lemak': 518,
#  'Hjh Maimunah Restaurant': 519,
#  '8 Korean BBQ': 520,
#  'Fu Zhou Poh Hwa Oyster Cake': 521,
#  'Okinawan Diner Nirai-Kanai': 522,
#  'Sushi Ichi': 523,
#  'Ambrosia Cafe': 524,
#  'Sum Kee': 525,
#  'Queensway Lau Tan Tutu Kueh': 526,
#  'Coastes': 527,
#  'The Landing Point - Fullerton Bay Hotel': 528,
#  'Ginza Anzu': 529,
#  'Real Food': 530,
#  'SKIRT': 531,
#  'Clinton Street Baking Company & Restaurant': 532,
#  'Chuan Kee Boneless Braised Duck': 533,
#  'Symmetry': 534,
#  'Akira Back': 535,
#  'Lei Garden': 536,
#  'Triple Three': 537,
#  'Lian He Ben Ji Claypot Rice': 538,
#  'Wah Lok Cantonese Restaurant': 539,
#  'Teochew Handmade Pau': 540,
#  'Sushi Kou': 541,
#  'Xiang Yuan Ji - Shanghai Sheng Jian Bao': 542,
#  'PP 881 Eating House': 543,
#  'Chin Chin Restaurant': 544,
#  'OverEasy': 545,
#  'Hokkaido Menya Kaiko': 546,
#  'Hillman Restaurant': 547,
#  "Auntie Kim's Korean Restaurant": 548,
#  'Tong Ah Eating House': 549,
#  'Vasco': 550,
#  'Raj Wines': 551,
#  'Shinji By Kanesaka': 552,
#  'Long Phung Vietnamese Restaurant': 553,
#  'La Petite Cuisine': 554,
#  'Old Long House Popiah': 555,
#  'Geylang Lor 9 Fresh Frog Leg Porridge': 556,
#  'Shisen Hanten': 557,
#  'Free the Robot': 558,
#  'City Satay Smith Street': 559,
#  "Muthu's Curry": 560,
#  'Boon Tong Kee Kway Chap': 561,
#  'Tanglin Crispy Curry Puff': 562,
#  'Play Nation': 563,
#  'Uno Beef House': 564,
#  'Rocky Master': 565,
#  'Blue Jasmine': 566,
#  'Cumi Bali': 567,
#  'Gram': 568,
#  'A Poke Theory': 569,
#  'Rafaels Bistro Singapore': 570,
#  'Happy Kampong Seafood': 571,
#  'Hanis': 572,
#  'E-Sarn Thai Cuisine': 573,
#  'Chinatown Seafood Restaurant': 574,
#  'Souper Tang': 575,
#  'Magurodonya Miuramisakikou Sushi': 576,
#  'The Curry Culture': 577,
#  'Dian Xiao Er': 578,
#  'The Mushroom Pot': 579,
#  "Lawry's The Prime Rib Singapore": 580,
#  'Decker Barbecue': 581,
#  'Gaufre Menn': 582,
#  'The Song of India': 583,
#  'Burmese Food': 584,
#  'Peranakan Flavors': 585,
#  'Mangiamo Pizzeria': 586,
#  'Shin Yuu Japanese Restaurant': 587,
#  'Leo Cafe & Restaurant': 588,
#  'Roast Paradise': 589,
#  'Wei Yi Laksa & Prawn Noodle': 590,
#  'Shah Alam': 591,
#  'Teahouse The Asian Kitchen': 592,
#  'Chikuyotei': 593,
#  'Bistro Du Vin': 594,
#  'BurgerLabo': 595,
#  'Boomarang': 596,
#  'Tapas Club': 597,
#  'The Rotisserie': 598,
#  'Grand Shanghai': 599,
#  'Tatsuya': 600,
#  'Supertree by Indochine': 601,
#  'Happy Chef Western Foods': 602,
#  'Kim Dae Mun': 603,
#  'Braci': 604,
#  'Taratata Brasserie': 605,
#  "Granny's Secret": 606,
#  'Pu3': 607,
#  'Gordon Grill': 608,
#  'Xin Shan Lian Zi Mei Bao Handmade Dim Sum': 609,
#  'Long Bar Steakhouse': 610,
#  "Ah Bong's Italian": 611,
#  'Singapore Fried Hokkien Mee': 612,
#  '13 STAGES': 613,
#  'Yamagawa Japanese Restaurant': 614,
#  'Esquina': 615,
#  'Violet Oon': 616,
#  'Dragon Phoenix': 617,
#  'Kebabs n Curries': 618,
#  'Dehesa': 619,
#  '13% Gastro Wine': 620,
#  'Daessiksin Korean BBQ': 621,
#  'Les Amis': 622,
#  'La Ristrettos': 623,
#  'Trattoria da Mimmo': 624,
#  'Ser Seng Herbs': 625,
#  'Riders Cafe': 626,
#  'Eight Treasures Vegetarian': 627,
#  'Sinn Ji Hainanese Chicken Rice': 628,
#  'Piedra Negra': 629,
#  'One Man Coffee': 630,
#  'Patisserie G': 631,
#  'Teochew Kway Tiao Soup': 632,
#  'Nassim Hill Bakery Bistro Bar': 633,
#  'Punch': 634,
#  'Whisk Cafe': 635,
#  '126 Eating House': 636,
#  'Latteria Mozzarella Bar': 637,
#  'Food Opera': 638,
#  'Tenshin': 639,
#  "Ah Ter's Fishball Minced Meat Noodles": 640,
#  'Komala Vilas': 641,
#  'No. 3 Crab Delicacy Seafood Restaurant': 642,
#  "Oscar's": 643,
#  'Meta Restaurant': 644,
#  'Bincho at Hua Bee': 645,
#  'Muay Thai Food': 646,
#  'ParaThai': 647,
#  'Marutama Ramen': 648,
#  'Hainan Chicken Rice Balls': 649,
#  'Hand in Hand Beijing': 650,
#  'timbre+': 651,
#  "Victor's Kitchen": 652,
#  'Crystal Jade La Mian Xiao Long Bao': 653,
#  'Bali Thai': 654,
#  'Gyoza-Ya': 655,
#  'Bahn Beer Thai Restaurant': 656,
#  'Nami': 657,
#  'Pizza Fabbrica': 658,
#  'Pasha': 659,
#  'Braseiro': 660,
#  'The Wall': 661,
#  'Ramen Nagi Singapore': 662,
#  'Spizza': 663,
#  'Pastaria Abate': 664,
#  'WANNA CUPPA': 665,
#  'Opus Bar & Grill': 666,
#  'Jing Hua Xiao Chi': 667,
#  'Nana Teh Tarik': 668,
#  'Kaiseki Yoshiyuki': 669,
#  'Harvest Seafood Restaurant': 670,
#  'Raja Bojun Sri Lankan Food': 671,
#  'Tambuah Mas': 672,
#  'Gyu Kaku Japanese BBQ': 673,
#  'Burger Joint': 674,
#  '1933': 675,
#  'Silk Road': 676,
#  'Tanuki Raw at Kapok': 677,
#  "Margarita's Dempsey Hill": 678,
#  'Gokul Vegetarian Restaurant and Cafe': 679,
#  'En Sushi': 680,
#  'Kimchi Xpress': 681,
#  'Shabu Shabu Tajimaya': 682,
#  'Etna Italian Restaurant': 683,
#  'Nanbantei Japanese': 684,
#  'Tomo Izakaya': 685,
#  'Kitchen by Food Rebel': 686,
#  'Garibaldi Italian Restaurant & Bar': 687,
#  'Fatty Aunt Yong Tau Foo': 688,
#  'Korean Fusion BBQ': 689,
#  'Jewel Coffee': 690,
#  'Marble Bistro': 691,
#  'Arunachala Bhavan': 692,
#  'Da Dong Prawn Noodles': 693,
#  "Lola's Cafe": 694,
#  'The Refinery': 695,
#  'Istanblue Mezze & Grill House': 696,
#  'Jing': 697,
#  'Good Chance Popiah Eating House': 698,
#  'Cherry Garden': 699,
#  'Beauty in the Pot': 700,
#  'Claypot & Cooked Food Kitchen': 701,
#  'Tuan Yuan Pork Ribs Soup': 702,
#  'Mr Biryani': 703,
#  '10 at Claymore': 704,
#  'Ciao Italian Risto Bar': 705,
#  'Idealite': 706,
#  'Amýýýý': 707,
#  'Cafe Melba': 708,
#  'Yaki Yaki Bo Teppanyaki Restaurant': 709,
#  'Sabai': 710,
#  'Supreme Tastes Jiang Nan Cuisine': 711,
#  'Toon Food House': 712,
#  "Adam's Corner": 713,
#  'The Hangar': 714,
#  'FOC PIM PAM': 715,
#  "Jai's Thai-Vientiane Cuisine": 716,
#  'Genesis Vegan Restaurant': 717,
#  'Warung Aneka Rasa': 718,
#  'Gayatri Restaurant': 719,
#  'Brotzeit': 720,
#  'Ocean Curry Fish Head': 721,
#  'Sun Moon': 722,
#  "Huber's Bistro": 723,
#  'The Carvery': 724,
#  'Kuriya Dining': 725,
#  'Ramen Bari-Uma': 726,
#  'The Tuckshop': 727,
#  'Teppanyaki - Food Junction - Bugis Junction': 728,
#  'Greenwood Fish Market & Bistro': 729,
#  'Chapter 55': 730,
#  'Tiong Bahru Boneless Hainanese Chicken Rice': 731,
#  'Hakumai': 732,
#  'Hainan Cooked Food Stall': 733,
#  'China Whampoa Home Made Noodle': 734,
#  'Koo Kee Yong Tow Foo Mee': 735,
#  'Mansaku': 736,
#  'Soup Restaurant': 737,
#  'Sen Of Japan': 738,
#  'Ah Hoe Mee Pok': 739,
#  'Jewel Coffee at Millenia Walk': 740,
#  'Pura Brasa': 741,
#  'La Pizzaiola': 742,
#  'Hong Sheng Restaurant': 743,
#  'Orignal Serangoon Fried Hokkien Mee': 744,
#  'Fratini La Trattoria': 745,
#  'Crystal Jade Golden Palace': 746,
#  'Brasserie Gavroche': 747,
#  'Geylang Prawn Noodle': 748,
#  'Wasabitei Japanese Cuisine': 749,
#  'Sideways': 750,
#  'Szechuan Court & Kitchen': 751,
#  'House of Commons': 752,
#  'Roland': 753,
#  'Seng Kee The Black Seed By Chef Benny': 754,
#  'Rongheng Seafood': 755,
#  'Majestic Bay': 756,
#  'FYR Cycene Ond Drinc': 757,
#  'Lee Fun Nam Kee Chicken Rice & Restaurant': 758,
#  'New Ubin': 759,
#  'Nan Hwa Chong Fish-Head Steamboat Corner': 760,
#  'Cove 99': 761,
#  'New York Pizza Factory': 762,
#  'Da Paolo Gastronomia - Orchard Paragon': 763,
#  'Coq & Balls': 764,
#  'Sakurazaka': 765,
#  'Bai Nian Yong Tau Foo': 766,
#  'Pondok': 767,
#  'Hock Lee Fish Ball Noodle': 768,
#  'Shan E Punjab': 769}

# %%
reviews['enum_restaurant'] = reviews['restaurant'].apply(lambda x : restaurant_dict[x])

# %%
plt.hist(reviews['enum_restaurant'], color = 'blue', edgecolor = 'black',bins = int(180/5))
plt.title("Frequency of Reviews each Restaurant")
plt.xlabel("enum_restaurant")
plt.ylabel("Frequency of Reviews")
# Out:
# Text(0,0.5,'Frequency of Reviews')

# %%
reviews['stars'].value_counts().plot('bar')
plt.title("Frequency of Reviews for each Star")
plt.xlabel("Stars Awarded")
plt.ylabel("Frequency of Restaurants")
# Out:
# Text(0,0.5,'Frequency of Restaurants')
